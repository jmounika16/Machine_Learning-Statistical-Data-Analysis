# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Mounika Jetti</p>

# %% [markdown]
# # CMSE 201: Quiz 2 (Section 007 - Fall 2020)
#
# The goal of this quiz is to give you the opportunity to test out some of the skills that you've developed thus far this semester. In particular, you'll reflect on what you know about writing code using Python and showcase some of your new programming skills.
#
# **Important note about using online resources**: This exam is "open internet". That means that you can look up documentation, google how to accomplish certain Python tasks, etc. Being able to effectively use the internet for computational modeling and data science is a very important skill, so we want to make sure you have the opportunity to exercise that skill. **However, the use of any person-to-person communication software is absolutely not acceptable.**
#
# **Do your own work.** This quiz is designed to give *you* the opportunity to show the instructor what you can do and you should hold yourself accountable for maintaining a high level of academic integrity. Any violation of academic integrity could result in you receiving a zero on the quiz.

# %% [markdown]
# ### Content knowledge and skills being tested
# #### Content:
# * Using functions to repeat the same operation multiple times
# * Reading in data from files
# * Making informative plots of data
#
#
# #### Skills/Practices:
# * Planning out a problem using pseudocode
# * Translating pseudocode to real code
# * Using best practices when writing your code

# %% [markdown]
# # Academic integrity statement [10 points]
#
# In the markdown cell below, put your personal academic integrity statement. By including this statement, you are confirming that you are submitting this as your own work and not that of someone else.

# %% [markdown]
# <font size=+3>&#9998;</font>
# * I Mounika Jetti,  commit to do all my work with complete honesty and without mis-using any resourses in a wrongful way. And commit to my work to the best of my ability. I aknowledge that I am aware of MSU ethical standards for integrity.*

# %% [markdown]
# ---
#
# # Question 1
#
# You’re working at a non-profit that partners with the United Nations to track population growth for different countries. Your boss has a presentation coming up with her boss and **she needs you to write a piece of code that can make plots that show population growth over time.**
#
# Since these plots will be used for her presentation, the plot should have **Descriptive axes labels** and **a title describing what the plot is showing**
#
# Your boss tells you that your code will be incorporated into a larger piece of code running analysis on the population data. This means that, since other people will be working with it:
# * **Your code should be self-contained and out of the way (i.e., it should be written as a function)**
# * **Your code should follow best practices (i.e., have informative variable names, include comments, etc.)**
#
#
# Your boss gives you an example of what the population data will look like, so you can test your code.

# %% [markdown]
# &#9989;&nbsp; **Part 1 (15 points):** Examine the data file and give a short description of how it is laid out.

# %% [markdown]
# <font size=+3>&#9998;</font> *Data has three columns. Country,year and total population. Dataset seems to be a time-series data where it has how population changed over the years of a country*

# %% [markdown]
# &#9989;&nbsp; **Part 2 (25 points):** Write out a plain language explanation for how you would solve this problem (i.e., write out a solution using pseudocode). You should assume that the other parts of the code will pass your function the name of the file with the data in it.

# %% [markdown]
# <font size=+3>&#9998;</font> *I will first load data into a dataframe. I will drop Country column from the dataframe. sort data based on Time column in ascending order. Use pct_change method to calculate percentage change of population in each row with previous row and take this into a new variable. Then, i will take Total population data from this dataframe to a variable named `population`. Take `Time` column from original dataframe into a variable named `years`. Use matplotlib's plotting function `plot` to plot a line plot between year and  total population. I will update x axis and y axis labels using xlabel and ylabel methods. I will also update title using title method of matplotlib *

# %% [markdown]
# &#9989;&nbsp; **Part 2 (40 points):** Translate your pseudocode into actual code.

# %%
# Put your code here
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,5)
def plot_data(dataset_path, delimiter=","):
    df = pd.read_csv("population_data.csv", sep=delimiter)
    df = df[['Time','Total Population']]
    df = df.sort_values('Time')
    df_pct_change = df.pct_change()
    years = df['Time']
    population = df_pct_change['Total Population']
    plt.plot(years,population)
    plt.xlabel("Years")
    plt.ylabel("Percentage change in Total population")
    plt.title("Growth of population over years")
plot_data('population_data.csv')

# %% [markdown]
# &#9989;&nbsp; **Part 3 (10 points):** Explain how you know that your code is working correctly.

# %% [markdown]
# <font size=+3>&#9998;</font> *I have verified couple of data points in the plot. I took the percentage change in the dataframe and checked if the data plotted is the same.*

# %% [markdown]
# I took exactly 25 min to complete the quiz.

# %% [markdown]
# ## When you are Finished
#
# ### MAKE SURE THAT YOU UPLOAD THE FILE WITH YOUR ANSWERS (I.E., NOT THE EMPTY FILE THAT YOU DOWNLOADED)
#
# Have a great weekend!
